# %%
from transform_openbrewery_silver import run

run()

# %%
# %sql
SELECT *
FROM silver.openbrewery
LIMIT 10;

# %%
# %sql
SHOW PARTITIONS silver.openbrewery

# %%
# %sql
SELECT count(*) 
FROM silver.openbrewery
WHERE id IS NULL;
